# %%
import pandas as pd

# %%
fifa = pd.read_csv('fifa21_raw_data.csv',nrows=5)

# %%
print(fifa.columns)
# Out:
# Index(['photoUrl', 'LongName', 'playerUrl', 'Nationality', 'Positions', 'Name',
#        'Age', '↓OVA', 'POT', 'Team & Contract', 'ID', 'Height', 'Weight',
#        'foot', 'BOV', 'BP', 'Growth', 'Joined', 'Loan Date End', 'Value',
#        'Wage', 'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
#        'Base Stats', 'W/F', 'SM', 'A/W', 'D/W', 'IR', 'PAC', 'SHO', 'PAS',
#        'DRI', 'DEF', 'PHY', 'Hits'],
#       dtype='object')

# %%
fifa
# Out:
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                        LongName  \
# 0                  Lionel Messi
# 1  C. Ronaldo dos Santos Aveiro
# 2                     Jan Oblak
# 3               Kevin De Bruyne
# 4    Neymar da Silva Santos Jr.
#
#                                            playerUrl Nationality Positions  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina  RW ST CF
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal     ST LW
# 2  http://sofifa.com/player/200389/jan-oblak/210005/    Slovenia        GK
# 3  http://sofifa.com/player/192985/kevin-de-bruyn...     Belgium    CAM CM
# 4  http://sofifa.com/player/190871/neymar-da-silv...      Brazil    LW CAM
#
#                 Name  Age  ↓OVA  POT  \
# 0           L. Messi   33    93   93
# 1  Cristiano Ronaldo   35    92   92
# 2           J. Oblak   27    91   93
# 3       K. De Bruyne   29    91   91
# 4          Neymar Jr   28    91   91
#
#                                 Team & Contract  ...     A/W     D/W   IR PAC  \
# 0         \n\n\n\nFC Barcelona\n2004 ~ 2021\n\n  ...  Medium     Low  5 ★  85
# 1             \n\n\n\nJuventus\n2018 ~ 2022\n\n  ...    High     Low  5 ★  89
# 2      \n\n\n\nAtlético Madrid\n2014 ~ 2023\n\n  ...  Medium  Medium  3 ★  87
# 3      \n\n\n\nManchester City\n2015 ~ 2023\n\n  ...    High    High  4 ★  76
# 4  \n\n\n\nParis Saint-Germain\n2017 ~ 2022\n\n  ...    High  Medium  5 ★  91
#
#    SHO PAS  DRI DEF  PHY Hits
# 0   92  91   95  38   65  372
# 1   93  81   89  35   77  344
# 2   92  78   90  52   90   86
# 3   86  93   88  64   78  163
# 4   85  86   94  36   59  273
#
# [5 rows x 77 columns]

# %%
fifa = pd.read_csv('fifa21_raw_data.csv',dtype={76: str})

# %%
fifa
# Out:
#                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# 2      https://cdn.sofifa.com/players/200/389/21_60.png
# 3      https://cdn.sofifa.com/players/192/985/21_60.png
# 4      https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                 ...
# 18974  https://cdn.sofifa.com/players/257/710/21_60.png
# 18975  https://cdn.sofifa.com/players/258/736/21_60.png
# 18976  https://cdn.sofifa.com/players/247/223/21_60.png
# 18977  https://cdn.sofifa.com/players/258/760/21_60.png
# 18978  https://cdn.sofifa.com/players/255/958/21_60.png
#
#                            LongName  \
# 0                      Lionel Messi
# 1      C. Ronaldo dos Santos Aveiro
# 2                         Jan Oblak
# 3                   Kevin De Bruyne
# 4        Neymar da Silva Santos Jr.
# ...                             ...
# 18974                Mengxuan Zhang
# 18975                 Vani Da Silva
# 18976                        Ao Xia
# 18977                     Ben Hough
# 18978                  Mateo Flores
#
#                                                playerUrl Nationality  \
# 0      http://sofifa.com/player/158023/lionel-messi/2...   Argentina
# 1      http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal
# 2      http://sofifa.com/player/200389/jan-oblak/210005/    Slovenia
# 3      http://sofifa.com/player/192985/kevin-de-bruyn...     Belgium
# 4      http://sofifa.com/player/190871/neymar-da-silv...      Brazil
# ...                                                  ...         ...
# 18974  http://sofifa.com/player/257710/mengxuan-zhang...    China PR
# 18975  http://sofifa.com/player/258736/vani-da-silva/...     England
# 18976     http://sofifa.com/player/247223/ao-xia/210005/    China PR
# 18977  http://sofifa.com/player/258760/ben-hough/210005/     England
# 18978  http://sofifa.com/player/255958/mateo-flores/2...     Bolivia
#
#       Positions               Name  Age  ↓OVA  POT  \
# 0      RW ST CF           L. Messi   33    93   93
# 1         ST LW  Cristiano Ronaldo   35    92   92
# 2            GK           J. Oblak   27    91   93
# 3        CAM CM       K. De Bruyne   29    91   91
# 4        LW CAM          Neymar Jr   28    91   91
# ...         ...                ...  ...   ...  ...
# 18974        CB     Zhang Mengxuan   21    47   52
# 18975        ST        V. Da Silva   17    47   67
# 18976        CB             Xia Ao   21    47   55
# 18977        CM           B. Hough   17    47   67
# 18978       CDM          M. Flores   19    47   63
#
#                                          Team & Contract  ...     A/W     D/W  \
# 0                  \n\n\n\nFC Barcelona\n2004 ~ 2021\n\n  ...  Medium     Low
# 1                      \n\n\n\nJuventus\n2018 ~ 2022\n\n  ...    High     Low
# 2               \n\n\n\nAtlético Madrid\n2014 ~ 2023\n\n  ...  Medium  Medium
# 3               \n\n\n\nManchester City\n2015 ~ 2023\n\n  ...    High    High
# 4           \n\n\n\nParis Saint-Germain\n2017 ~ 2022\n\n  ...    High  Medium
# ...                                                  ...  ...     ...     ...
# 18974  \n\n\n\nChongqing Dangdai Lifan FC SWM Team\n2...  ...     Low     Low
# 18975           \n\n\n\nOldham Athletic\n2020 ~ 2021\n\n  ...  Medium  Medium
# 18976                \n\n\n\nWuhan Zall\n2018 ~ 2022\n\n  ...  Medium  Medium
# 18977           \n\n\n\nOldham Athletic\n2020 ~ 2021\n\n  ...  Medium  Medium
# 18978              \n\n\n\nClub Bolívar\n2020 ~ 2024\n\n  ...  Medium  Medium
#
#         IR PAC  SHO PAS  DRI DEF PHY   Hits
# 0      5 ★  85   92  91   95  38  65  \n372
# 1      5 ★  89   93  81   89  35  77  \n344
# 2      3 ★  87   92  78   90  52  90   \n86
# 3      4 ★  76   86  93   88  64  78  \n163
# 4      5 ★  91   85  86   94  36  59  \n273
# ...    ...  ..  ...  ..  ...  ..  ..    ...
# 18974  1 ★  58   23  26   27  50  48    \n2
# 18975  1 ★  70   46  40   53  16  40    \n3
# 18976  1 ★  64   28  26   38  48  51    \n3
# 18977  1 ★  64   40  48   49  35  45    \n5
# 18978  1 ★  57   32  43   48  44  49    \n2
#
# [18979 rows x 77 columns]

# %%
fifa1=fifa.copy()

# %%
fifa
# Out:
#                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# 2      https://cdn.sofifa.com/players/200/389/21_60.png
# 3      https://cdn.sofifa.com/players/192/985/21_60.png
# 4      https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                 ...
# 18974  https://cdn.sofifa.com/players/257/710/21_60.png
# 18975  https://cdn.sofifa.com/players/258/736/21_60.png
# 18976  https://cdn.sofifa.com/players/247/223/21_60.png
# 18977  https://cdn.sofifa.com/players/258/760/21_60.png
# 18978  https://cdn.sofifa.com/players/255/958/21_60.png
#
#                            LongName  \
# 0                      Lionel Messi
# 1      C. Ronaldo dos Santos Aveiro
# 2                         Jan Oblak
# 3                   Kevin De Bruyne
# 4        Neymar da Silva Santos Jr.
# ...                             ...
# 18974                Mengxuan Zhang
# 18975                 Vani Da Silva
# 18976                        Ao Xia
# 18977                     Ben Hough
# 18978                  Mateo Flores
#
#                                                playerUrl Nationality  \
# 0      http://sofifa.com/player/158023/lionel-messi/2...   Argentina
# 1      http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal
# 2      http://sofifa.com/player/200389/jan-oblak/210005/    Slovenia
# 3      http://sofifa.com/player/192985/kevin-de-bruyn...     Belgium
# 4      http://sofifa.com/player/190871/neymar-da-silv...      Brazil
# ...                                                  ...         ...
# 18974  http://sofifa.com/player/257710/mengxuan-zhang...    China PR
# 18975  http://sofifa.com/player/258736/vani-da-silva/...     England
# 18976     http://sofifa.com/player/247223/ao-xia/210005/    China PR
# 18977  http://sofifa.com/player/258760/ben-hough/210005/     England
# 18978  http://sofifa.com/player/255958/mateo-flores/2...     Bolivia
#
#       Positions               Name  Age  ↓OVA  POT  \
# 0      RW ST CF           L. Messi   33    93   93
# 1         ST LW  Cristiano Ronaldo   35    92   92
# 2            GK           J. Oblak   27    91   93
# 3        CAM CM       K. De Bruyne   29    91   91
# 4        LW CAM          Neymar Jr   28    91   91
# ...         ...                ...  ...   ...  ...
# 18974        CB     Zhang Mengxuan   21    47   52
# 18975        ST        V. Da Silva   17    47   67
# 18976        CB             Xia Ao   21    47   55
# 18977        CM           B. Hough   17    47   67
# 18978       CDM          M. Flores   19    47   63
#
#                                          Team & Contract  ...     A/W     D/W  \
# 0                  \n\n\n\nFC Barcelona\n2004 ~ 2021\n\n  ...  Medium     Low
# 1                      \n\n\n\nJuventus\n2018 ~ 2022\n\n  ...    High     Low
# 2               \n\n\n\nAtlético Madrid\n2014 ~ 2023\n\n  ...  Medium  Medium
# 3               \n\n\n\nManchester City\n2015 ~ 2023\n\n  ...    High    High
# 4           \n\n\n\nParis Saint-Germain\n2017 ~ 2022\n\n  ...    High  Medium
# ...                                                  ...  ...     ...     ...
# 18974  \n\n\n\nChongqing Dangdai Lifan FC SWM Team\n2...  ...     Low     Low
# 18975           \n\n\n\nOldham Athletic\n2020 ~ 2021\n\n  ...  Medium  Medium
# 18976                \n\n\n\nWuhan Zall\n2018 ~ 2022\n\n  ...  Medium  Medium
# 18977           \n\n\n\nOldham Athletic\n2020 ~ 2021\n\n  ...  Medium  Medium
# 18978              \n\n\n\nClub Bolívar\n2020 ~ 2024\n\n  ...  Medium  Medium
#
#         IR PAC  SHO PAS  DRI DEF PHY   Hits
# 0      5 ★  85   92  91   95  38  65  \n372
# 1      5 ★  89   93  81   89  35  77  \n344
# 2      3 ★  87   92  78   90  52  90   \n86
# 3      4 ★  76   86  93   88  64  78  \n163
# 4      5 ★  91   85  86   94  36  59  \n273
# ...    ...  ..  ...  ..  ...  ..  ..    ...
# 18974  1 ★  58   23  26   27  50  48    \n2
# 18975  1 ★  70   46  40   53  16  40    \n3
# 18976  1 ★  64   28  26   38  48  51    \n3
# 18977  1 ★  64   40  48   49  35  45    \n5
# 18978  1 ★  57   32  43   48  44  49    \n2
#
# [18979 rows x 77 columns]

# %%
fifa.columns
# Out:
# Index(['photoUrl', 'LongName', 'playerUrl', 'Nationality', 'Positions', 'Name',
#        'Age', '↓OVA', 'POT', 'Team & Contract', 'ID', 'Height', 'Weight',
#        'foot', 'BOV', 'BP', 'Growth', 'Joined', 'Loan Date End', 'Value',
#        'Wage', 'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
#        'Base Stats', 'W/F', 'SM', 'A/W', 'D/W', 'IR', 'PAC', 'SHO', 'PAS',
#        'DRI', 'DEF', 'PHY', 'Hits'],
#       dtype='object')

# %%
fifa.drop(['photoUrl','LongName','playerUrl'], inplace = True, axis = 1)

# %%
fifa
# Out:
#       Nationality Positions               Name  Age  ↓OVA  POT  \
# 0       Argentina  RW ST CF           L. Messi   33    93   93
# 1        Portugal     ST LW  Cristiano Ronaldo   35    92   92
# 2        Slovenia        GK           J. Oblak   27    91   93
# 3         Belgium    CAM CM       K. De Bruyne   29    91   91
# 4          Brazil    LW CAM          Neymar Jr   28    91   91
# ...           ...       ...                ...  ...   ...  ...
# 18974    China PR        CB     Zhang Mengxuan   21    47   52
# 18975     England        ST        V. Da Silva   17    47   67
# 18976    China PR        CB             Xia Ao   21    47   55
# 18977     England        CM           B. Hough   17    47   67
# 18978     Bolivia       CDM          M. Flores   19    47   63
#
#                                          Team & Contract      ID Height  \
# 0                  \n\n\n\nFC Barcelona\n2004 ~ 2021\n\n  158023   5'7"
# 1                      \n\n\n\nJuventus\n2018 ~ 2022\n\n   20801   6'2"
# 2               \n\n\n\nAtlético Madrid\n2014 ~ 2023\n\n  200389   6'2"
# 3               \n\n\n\nManchester City\n2015 ~ 2023\n\n  192985  5'11"
# 4           \n\n\n\nParis Saint-Germain\n2017 ~ 2022\n\n  190871   5'9"
# ...                                                  ...     ...    ...
# 18974  \n\n\n\nChongqing Dangdai Lifan FC SWM Team\n2...  257710  5'10"
# 18975           \n\n\n\nOldham Athletic\n2020 ~ 2021\n\n  258736   5'7"
# 18976                \n\n\n\nWuhan Zall\n2018 ~ 2022\n\n  247223  5'10"
# 18977           \n\n\n\nOldham Athletic\n2020 ~ 2021\n\n  258760   5'9"
# 18978              \n\n\n\nClub Bolívar\n2020 ~ 2024\n\n  255958   5'9"
#
#        Weight  ...     A/W     D/W   IR  PAC SHO PAS DRI DEF PHY   Hits
# 0      159lbs  ...  Medium     Low  5 ★   85  92  91  95  38  65  \n372
# 1      183lbs  ...    High     Low  5 ★   89  93  81  89  35  77  \n344
# 2      192lbs  ...  Medium  Medium  3 ★   87  92  78  90  52  90   \n86
# 3      154lbs  ...    High    High  4 ★   76  86  93  88  64  78  \n163
# 4      150lbs  ...    High  Medium  5 ★   91  85  86  94  36  59  \n273
# ...       ...  ...     ...     ...  ...  ...  ..  ..  ..  ..  ..    ...
# 18974  154lbs  ...     Low     Low  1 ★   58  23  26  27  50  48    \n2
# 18975  128lbs  ...  Medium  Medium  1 ★   70  46  40  53  16  40    \n3
# 18976  146lbs  ...  Medium  Medium  1 ★   64  28  26  38  48  51    \n3
# 18977  143lbs  ...  Medium  Medium  1 ★   64  40  48  49  35  45    \n5
# 18978  150lbs  ...  Medium  Medium  1 ★   57  32  43  48  44  49    \n2
#
# [18979 rows x 74 columns]

# %%
fifa = fifa.rename({'↓OVA' : 'OVA'}, axis = 1)

# %%
fifa
# Out:
#       Nationality Positions               Name  Age  OVA  POT  \
# 0       Argentina  RW ST CF           L. Messi   33   93   93
# 1        Portugal     ST LW  Cristiano Ronaldo   35   92   92
# 2        Slovenia        GK           J. Oblak   27   91   93
# 3         Belgium    CAM CM       K. De Bruyne   29   91   91
# 4          Brazil    LW CAM          Neymar Jr   28   91   91
# ...           ...       ...                ...  ...  ...  ...
# 18974    China PR        CB     Zhang Mengxuan   21   47   52
# 18975     England        ST        V. Da Silva   17   47   67
# 18976    China PR        CB             Xia Ao   21   47   55
# 18977     England        CM           B. Hough   17   47   67
# 18978     Bolivia       CDM          M. Flores   19   47   63
#
#                                          Team & Contract      ID Height  \
# 0                  \n\n\n\nFC Barcelona\n2004 ~ 2021\n\n  158023   5'7"
# 1                      \n\n\n\nJuventus\n2018 ~ 2022\n\n   20801   6'2"
# 2               \n\n\n\nAtlético Madrid\n2014 ~ 2023\n\n  200389   6'2"
# 3               \n\n\n\nManchester City\n2015 ~ 2023\n\n  192985  5'11"
# 4           \n\n\n\nParis Saint-Germain\n2017 ~ 2022\n\n  190871   5'9"
# ...                                                  ...     ...    ...
# 18974  \n\n\n\nChongqing Dangdai Lifan FC SWM Team\n2...  257710  5'10"
# 18975           \n\n\n\nOldham Athletic\n2020 ~ 2021\n\n  258736   5'7"
# 18976                \n\n\n\nWuhan Zall\n2018 ~ 2022\n\n  247223  5'10"
# 18977           \n\n\n\nOldham Athletic\n2020 ~ 2021\n\n  258760   5'9"
# 18978              \n\n\n\nClub Bolívar\n2020 ~ 2024\n\n  255958   5'9"
#
#        Weight  ...     A/W     D/W   IR  PAC SHO PAS DRI DEF PHY   Hits
# 0      159lbs  ...  Medium     Low  5 ★   85  92  91  95  38  65  \n372
# 1      183lbs  ...    High     Low  5 ★   89  93  81  89  35  77  \n344
# 2      192lbs  ...  Medium  Medium  3 ★   87  92  78  90  52  90   \n86
# 3      154lbs  ...    High    High  4 ★   76  86  93  88  64  78  \n163
# 4      150lbs  ...    High  Medium  5 ★   91  85  86  94  36  59  \n273
# ...       ...  ...     ...     ...  ...  ...  ..  ..  ..  ..  ..    ...
# 18974  154lbs  ...     Low     Low  1 ★   58  23  26  27  50  48    \n2
# 18975  128lbs  ...  Medium  Medium  1 ★   70  46  40  53  16  40    \n3
# 18976  146lbs  ...  Medium  Medium  1 ★   64  28  26  38  48  51    \n3
# 18977  143lbs  ...  Medium  Medium  1 ★   64  40  48  49  35  45    \n5
# 18978  150lbs  ...  Medium  Medium  1 ★   57  32  43  48  44  49    \n2
#
# [18979 rows x 74 columns]

# %%
fifa['Team & Contract'] = fifa['Team & Contract'].str.strip("\r\n\r\n\r\n\r\n")

# %%
fifa
# Out:
#       Nationality Positions               Name  Age  OVA  POT  \
# 0       Argentina  RW ST CF           L. Messi   33   93   93
# 1        Portugal     ST LW  Cristiano Ronaldo   35   92   92
# 2        Slovenia        GK           J. Oblak   27   91   93
# 3         Belgium    CAM CM       K. De Bruyne   29   91   91
# 4          Brazil    LW CAM          Neymar Jr   28   91   91
# ...           ...       ...                ...  ...  ...  ...
# 18974    China PR        CB     Zhang Mengxuan   21   47   52
# 18975     England        ST        V. Da Silva   17   47   67
# 18976    China PR        CB             Xia Ao   21   47   55
# 18977     England        CM           B. Hough   17   47   67
# 18978     Bolivia       CDM          M. Flores   19   47   63
#
#                                         Team & Contract      ID Height  \
# 0                             FC Barcelona\n2004 ~ 2021  158023   5'7"
# 1                                 Juventus\n2018 ~ 2022   20801   6'2"
# 2                          Atlético Madrid\n2014 ~ 2023  200389   6'2"
# 3                          Manchester City\n2015 ~ 2023  192985  5'11"
# 4                      Paris Saint-Germain\n2017 ~ 2022  190871   5'9"
# ...                                                 ...     ...    ...
# 18974  Chongqing Dangdai Lifan FC SWM Team\n2020 ~ 2020  257710  5'10"
# 18975                      Oldham Athletic\n2020 ~ 2021  258736   5'7"
# 18976                           Wuhan Zall\n2018 ~ 2022  247223  5'10"
# 18977                      Oldham Athletic\n2020 ~ 2021  258760   5'9"
# 18978                         Club Bolívar\n2020 ~ 2024  255958   5'9"
#
#        Weight  ...     A/W     D/W   IR  PAC SHO PAS DRI DEF PHY   Hits
# 0      159lbs  ...  Medium     Low  5 ★   85  92  91  95  38  65  \n372
# 1      183lbs  ...    High     Low  5 ★   89  93  81  89  35  77  \n344
# 2      192lbs  ...  Medium  Medium  3 ★   87  92  78  90  52  90   \n86
# 3      154lbs  ...    High    High  4 ★   76  86  93  88  64  78  \n163
# 4      150lbs  ...    High  Medium  5 ★   91  85  86  94  36  59  \n273
# ...       ...  ...     ...     ...  ...  ...  ..  ..  ..  ..  ..    ...
# 18974  154lbs  ...     Low     Low  1 ★   58  23  26  27  50  48    \n2
# 18975  128lbs  ...  Medium  Medium  1 ★   70  46  40  53  16  40    \n3
# 18976  146lbs  ...  Medium  Medium  1 ★   64  28  26  38  48  51    \n3
# 18977  143lbs  ...  Medium  Medium  1 ★   64  40  48  49  35  45    \n5
# 18978  150lbs  ...  Medium  Medium  1 ★   57  32  43  48  44  49    \n2
#
# [18979 rows x 74 columns]

# %%
fifa.duplicated().sum
# Out:
# <bound method Series.sum of 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18974    False
# 18975    False
# 18976    False
# 18977    False
# 18978    False
# Length: 18979, dtype: bool>

# %%
# Extracting team information from 'Team & Contract' column
fifa['Team'] = fifa['Team & Contract'].str.split('\n').str[1].str.strip()

# Extracting contract details (assuming contract information is contained in numbers and the tilde symbol)
fifa['Contract'] = fifa['Team & Contract'].str.extract(r'(\d{4}~?\d{4}|\d{4})')

# Extracting contract start year
fifa['Contract_start'] = fifa['Contract'].str.split('~').str[0].astype(int, errors='ignore')

# Extracting contract end year
fifa['Contract_end'] = fifa['Contract'].str.split('~').str[-1].astype(int, errors='ignore')

# Converting start and end contract years to numeric, handling errors with 'coerce' and filling missing values with 0
fifa['Contract_start'] = pd.to_numeric(fifa['Contract_start'], errors="coerce").fillna(0).astype(int)
fifa['Contract_end'] = pd.to_numeric(fifa['Contract_end'], errors="coerce").fillna(0).astype(int)

# %%
fifa['Teams'] = fifa['Team & Contract'].str.replace(r'\n.*', '', regex = True)

# %%
fifa
# Out:
#       Nationality Positions               Name  Age  OVA  POT  \
# 0       Argentina  RW ST CF           L. Messi   33   93   93
# 1        Portugal     ST LW  Cristiano Ronaldo   35   92   92
# 2        Slovenia        GK           J. Oblak   27   91   93
# 3         Belgium    CAM CM       K. De Bruyne   29   91   91
# 4          Brazil    LW CAM          Neymar Jr   28   91   91
# ...           ...       ...                ...  ...  ...  ...
# 18974    China PR        CB     Zhang Mengxuan   21   47   52
# 18975     England        ST        V. Da Silva   17   47   67
# 18976    China PR        CB             Xia Ao   21   47   55
# 18977     England        CM           B. Hough   17   47   67
# 18978     Bolivia       CDM          M. Flores   19   47   63
#
#                                         Team & Contract      ID Height  \
# 0                             FC Barcelona\n2004 ~ 2021  158023   5'7"
# 1                                 Juventus\n2018 ~ 2022   20801   6'2"
# 2                          Atlético Madrid\n2014 ~ 2023  200389   6'2"
# 3                          Manchester City\n2015 ~ 2023  192985  5'11"
# 4                      Paris Saint-Germain\n2017 ~ 2022  190871   5'9"
# ...                                                 ...     ...    ...
# 18974  Chongqing Dangdai Lifan FC SWM Team\n2020 ~ 2020  257710  5'10"
# 18975                      Oldham Athletic\n2020 ~ 2021  258736   5'7"
# 18976                           Wuhan Zall\n2018 ~ 2022  247223  5'10"
# 18977                      Oldham Athletic\n2020 ~ 2021  258760   5'9"
# 18978                         Club Bolívar\n2020 ~ 2024  255958   5'9"
#
#        Weight  ... PAS  DRI DEF  PHY   Hits         Team Contract  \
# 0      159lbs  ...  91   95  38   65  \n372  2004 ~ 2021     2004
# 1      183lbs  ...  81   89  35   77  \n344  2018 ~ 2022     2018
# 2      192lbs  ...  78   90  52   90   \n86  2014 ~ 2023     2014
# 3      154lbs  ...  93   88  64   78  \n163  2015 ~ 2023     2015
# 4      150lbs  ...  86   94  36   59  \n273  2017 ~ 2022     2017
# ...       ...  ...  ..  ...  ..  ...    ...          ...      ...
# 18974  154lbs  ...  26   27  50   48    \n2  2020 ~ 2020     2020
# 18975  128lbs  ...  40   53  16   40    \n3  2020 ~ 2021     2020
# 18976  146lbs  ...  26   38  48   51    \n3  2018 ~ 2022     2018
# 18977  143lbs  ...  48   49  35   45    \n5  2020 ~ 2021     2020
# 18978  150lbs  ...  43   48  44   49    \n2  2020 ~ 2024     2020
#
#       Contract_start Contract_end                                Teams
# 0               2004         2004                         FC Barcelona
# 1               2018         2018                             Juventus
# 2               2014         2014                      Atlético Madrid
# 3               2015         2015                      Manchester City
# 4               2017         2017                  Paris Saint-Germain
# ...              ...          ...                                  ...
# 18974           2020         2020  Chongqing Dangdai Lifan FC SWM Team
# 18975           2020         2020                      Oldham Athletic
# 18976           2018         2018                           Wuhan Zall
# 18977           2020         2020                      Oldham Athletic
# 18978           2020         2020                         Club Bolívar
#
# [18979 rows x 79 columns]

# %%
fifa.drop(['Team & Contract','Team','Contract'], inplace = True, axis =1)

# %%
fifa
# Out:
#       Nationality Positions               Name  Age  OVA  POT      ID Height  \
# 0       Argentina  RW ST CF           L. Messi   33   93   93  158023   5'7"
# 1        Portugal     ST LW  Cristiano Ronaldo   35   92   92   20801   6'2"
# 2        Slovenia        GK           J. Oblak   27   91   93  200389   6'2"
# 3         Belgium    CAM CM       K. De Bruyne   29   91   91  192985  5'11"
# 4          Brazil    LW CAM          Neymar Jr   28   91   91  190871   5'9"
# ...           ...       ...                ...  ...  ...  ...     ...    ...
# 18974    China PR        CB     Zhang Mengxuan   21   47   52  257710  5'10"
# 18975     England        ST        V. Da Silva   17   47   67  258736   5'7"
# 18976    China PR        CB             Xia Ao   21   47   55  247223  5'10"
# 18977     England        CM           B. Hough   17   47   67  258760   5'9"
# 18978     Bolivia       CDM          M. Flores   19   47   63  255958   5'9"
#
#        Weight   foot  ...  PAC SHO  PAS DRI DEF PHY   Hits Contract_start  \
# 0      159lbs   Left  ...   85  92   91  95  38  65  \n372           2004
# 1      183lbs  Right  ...   89  93   81  89  35  77  \n344           2018
# 2      192lbs  Right  ...   87  92   78  90  52  90   \n86           2014
# 3      154lbs  Right  ...   76  86   93  88  64  78  \n163           2015
# 4      150lbs  Right  ...   91  85   86  94  36  59  \n273           2017
# ...       ...    ...  ...  ...  ..  ...  ..  ..  ..    ...            ...
# 18974  154lbs  Right  ...   58  23   26  27  50  48    \n2           2020
# 18975  128lbs  Right  ...   70  46   40  53  16  40    \n3           2020
# 18976  146lbs  Right  ...   64  28   26  38  48  51    \n3           2018
# 18977  143lbs  Right  ...   64  40   48  49  35  45    \n5           2020
# 18978  150lbs  Right  ...   57  32   43  48  44  49    \n2           2020
#
#        Contract_end                                Teams
# 0              2004                         FC Barcelona
# 1              2018                             Juventus
# 2              2014                      Atlético Madrid
# 3              2015                      Manchester City
# 4              2017                  Paris Saint-Germain
# ...             ...                                  ...
# 18974          2020  Chongqing Dangdai Lifan FC SWM Team
# 18975          2020                      Oldham Athletic
# 18976          2018                           Wuhan Zall
# 18977          2020                      Oldham Athletic
# 18978          2020                         Club Bolívar
#
# [18979 rows x 76 columns]

# %%
fifa['Height']
# Out:
# 0         5'7"
# 1         6'2"
# 2         6'2"
# 3        5'11"
# 4         5'9"
#          ...
# 18974    5'10"
# 18975     5'7"
# 18976    5'10"
# 18977     5'9"
# 18978     5'9"
# Name: Height, Length: 18979, dtype: object

# %%
# Function to convert height from feet and inches to centimeters
def height_to_cm(height):
    # Split the height string by the apostrophe
    feet, inches = height.split("'")
    
    # Remove the double quote and convert inches to integer
    inches = inches.replace("\"", "")
    
    # Convert to total inches and then to cm
    total_inches = int(feet) * 12 + int(inches)
    return total_inches * 2.54

# Apply the function to the 'Height' column and create a new 'Height_cm' column
fifa['Height_cm'] = fifa['Height'].apply(height_to_cm)

# %%
fifa['Height_cm']
# Out:
# 0        170.18
# 1        187.96
# 2        187.96
# 3        180.34
# 4        175.26
#           ...
# 18974    177.80
# 18975    170.18
# 18976    177.80
# 18977    175.26
# 18978    175.26
# Name: Height_cm, Length: 18979, dtype: float64

# %%
# Function to convert height from feet and inches to centimeters
def height_to_cm(height):
    # Split the height string by the apostrophe
    feet, inches = height.split("'")
    
    # Remove the double quote and convert inches to integer
    inches = inches.replace("\"", "")
    
    # Convert to total inches and then to cm
    total_inches = int(feet) * 12 + int(inches)
    return total_inches * 2.54

# Apply the function to the 'Height' column, convert the result to int, and create a new 'Height_cm' column
fifa['Height_cm'] = fifa['Height'].apply(height_to_cm).round().astype(int)

# %%
fifa['Height_cm']
# Out:
# 0        170
# 1        188
# 2        188
# 3        180
# 4        175
#         ...
# 18974    178
# 18975    170
# 18976    178
# 18977    175
# 18978    175
# Name: Height_cm, Length: 18979, dtype: int32

# %%
fifa
# Out:
#       Nationality Positions               Name  Age  OVA  POT      ID Height  \
# 0       Argentina  RW ST CF           L. Messi   33   93   93  158023   5'7"
# 1        Portugal     ST LW  Cristiano Ronaldo   35   92   92   20801   6'2"
# 2        Slovenia        GK           J. Oblak   27   91   93  200389   6'2"
# 3         Belgium    CAM CM       K. De Bruyne   29   91   91  192985  5'11"
# 4          Brazil    LW CAM          Neymar Jr   28   91   91  190871   5'9"
# ...           ...       ...                ...  ...  ...  ...     ...    ...
# 18974    China PR        CB     Zhang Mengxuan   21   47   52  257710  5'10"
# 18975     England        ST        V. Da Silva   17   47   67  258736   5'7"
# 18976    China PR        CB             Xia Ao   21   47   55  247223  5'10"
# 18977     England        CM           B. Hough   17   47   67  258760   5'9"
# 18978     Bolivia       CDM          M. Flores   19   47   63  255958   5'9"
#
#        Weight   foot  ...  SHO PAS  DRI DEF PHY   Hits Contract_start  \
# 0      159lbs   Left  ...   92  91   95  38  65  \n372           2004
# 1      183lbs  Right  ...   93  81   89  35  77  \n344           2018
# 2      192lbs  Right  ...   92  78   90  52  90   \n86           2014
# 3      154lbs  Right  ...   86  93   88  64  78  \n163           2015
# 4      150lbs  Right  ...   85  86   94  36  59  \n273           2017
# ...       ...    ...  ...  ...  ..  ...  ..  ..    ...            ...
# 18974  154lbs  Right  ...   23  26   27  50  48    \n2           2020
# 18975  128lbs  Right  ...   46  40   53  16  40    \n3           2020
# 18976  146lbs  Right  ...   28  26   38  48  51    \n3           2018
# 18977  143lbs  Right  ...   40  48   49  35  45    \n5           2020
# 18978  150lbs  Right  ...   32  43   48  44  49    \n2           2020
#
#       Contract_end                                Teams  Height_cm
# 0             2004                         FC Barcelona        170
# 1             2018                             Juventus        188
# 2             2014                      Atlético Madrid        188
# 3             2015                      Manchester City        180
# 4             2017                  Paris Saint-Germain        175
# ...            ...                                  ...        ...
# 18974         2020  Chongqing Dangdai Lifan FC SWM Team        178
# 18975         2020                      Oldham Athletic        170
# 18976         2018                           Wuhan Zall        178
# 18977         2020                      Oldham Athletic        175
# 18978         2020                         Club Bolívar        175
#
# [18979 rows x 77 columns]

# %%
fifa.drop(['Height'], inplace = True, axis = 1)

# %%
fifa
# Out:
#       Nationality Positions               Name  Age  OVA  POT      ID  Weight  \
# 0       Argentina  RW ST CF           L. Messi   33   93   93  158023  159lbs
# 1        Portugal     ST LW  Cristiano Ronaldo   35   92   92   20801  183lbs
# 2        Slovenia        GK           J. Oblak   27   91   93  200389  192lbs
# 3         Belgium    CAM CM       K. De Bruyne   29   91   91  192985  154lbs
# 4          Brazil    LW CAM          Neymar Jr   28   91   91  190871  150lbs
# ...           ...       ...                ...  ...  ...  ...     ...     ...
# 18974    China PR        CB     Zhang Mengxuan   21   47   52  257710  154lbs
# 18975     England        ST        V. Da Silva   17   47   67  258736  128lbs
# 18976    China PR        CB             Xia Ao   21   47   55  247223  146lbs
# 18977     England        CM           B. Hough   17   47   67  258760  143lbs
# 18978     Bolivia       CDM          M. Flores   19   47   63  255958  150lbs
#
#         foot  BOV  ... SHO  PAS DRI DEF PHY   Hits Contract_start  \
# 0       Left   93  ...  92   91  95  38  65  \n372           2004
# 1      Right   92  ...  93   81  89  35  77  \n344           2018
# 2      Right   91  ...  92   78  90  52  90   \n86           2014
# 3      Right   91  ...  86   93  88  64  78  \n163           2015
# 4      Right   91  ...  85   86  94  36  59  \n273           2017
# ...      ...  ...  ...  ..  ...  ..  ..  ..    ...            ...
# 18974  Right   49  ...  23   26  27  50  48    \n2           2020
# 18975  Right   51  ...  46   40  53  16  40    \n3           2020
# 18976  Right   49  ...  28   26  38  48  51    \n3           2018
# 18977  Right   51  ...  40   48  49  35  45    \n5           2020
# 18978  Right   48  ...  32   43  48  44  49    \n2           2020
#
#        Contract_end                                Teams  Height_cm
# 0              2004                         FC Barcelona        170
# 1              2018                             Juventus        188
# 2              2014                      Atlético Madrid        188
# 3              2015                      Manchester City        180
# 4              2017                  Paris Saint-Germain        175
# ...             ...                                  ...        ...
# 18974          2020  Chongqing Dangdai Lifan FC SWM Team        178
# 18975          2020                      Oldham Athletic        170
# 18976          2018                           Wuhan Zall        178
# 18977          2020                      Oldham Athletic        175
# 18978          2020                         Club Bolívar        175
#
# [18979 rows x 76 columns]

# %%
# Remove non-numeric characters and convert the 'weight' column to integers
fifa['Weight'] = fifa['Weight'].str.replace(r'[^0-9]', '', regex=True).astype(int)

# %%
fifa
# Out:
#       Nationality Positions               Name  Age  OVA  POT      ID  Weight  \
# 0       Argentina  RW ST CF           L. Messi   33   93   93  158023     159
# 1        Portugal     ST LW  Cristiano Ronaldo   35   92   92   20801     183
# 2        Slovenia        GK           J. Oblak   27   91   93  200389     192
# 3         Belgium    CAM CM       K. De Bruyne   29   91   91  192985     154
# 4          Brazil    LW CAM          Neymar Jr   28   91   91  190871     150
# ...           ...       ...                ...  ...  ...  ...     ...     ...
# 18974    China PR        CB     Zhang Mengxuan   21   47   52  257710     154
# 18975     England        ST        V. Da Silva   17   47   67  258736     128
# 18976    China PR        CB             Xia Ao   21   47   55  247223     146
# 18977     England        CM           B. Hough   17   47   67  258760     143
# 18978     Bolivia       CDM          M. Flores   19   47   63  255958     150
#
#         foot  BOV  ... SHO  PAS DRI DEF PHY   Hits Contract_start  \
# 0       Left   93  ...  92   91  95  38  65  \n372           2004
# 1      Right   92  ...  93   81  89  35  77  \n344           2018
# 2      Right   91  ...  92   78  90  52  90   \n86           2014
# 3      Right   91  ...  86   93  88  64  78  \n163           2015
# 4      Right   91  ...  85   86  94  36  59  \n273           2017
# ...      ...  ...  ...  ..  ...  ..  ..  ..    ...            ...
# 18974  Right   49  ...  23   26  27  50  48    \n2           2020
# 18975  Right   51  ...  46   40  53  16  40    \n3           2020
# 18976  Right   49  ...  28   26  38  48  51    \n3           2018
# 18977  Right   51  ...  40   48  49  35  45    \n5           2020
# 18978  Right   48  ...  32   43  48  44  49    \n2           2020
#
#        Contract_end                                Teams  Height_cm
# 0              2004                         FC Barcelona        170
# 1              2018                             Juventus        188
# 2              2014                      Atlético Madrid        188
# 3              2015                      Manchester City        180
# 4              2017                  Paris Saint-Germain        175
# ...             ...                                  ...        ...
# 18974          2020  Chongqing Dangdai Lifan FC SWM Team        178
# 18975          2020                      Oldham Athletic        170
# 18976          2018                           Wuhan Zall        178
# 18977          2020                      Oldham Athletic        175
# 18978          2020                         Club Bolívar        175
#
# [18979 rows x 76 columns]

# %%
fifa = fifa.rename({"Weight": "Weight_lbs"}, axis =1)

# %%
fifa
# Out:
#       Nationality Positions               Name  Age  OVA  POT      ID  \
# 0       Argentina  RW ST CF           L. Messi   33   93   93  158023
# 1        Portugal     ST LW  Cristiano Ronaldo   35   92   92   20801
# 2        Slovenia        GK           J. Oblak   27   91   93  200389
# 3         Belgium    CAM CM       K. De Bruyne   29   91   91  192985
# 4          Brazil    LW CAM          Neymar Jr   28   91   91  190871
# ...           ...       ...                ...  ...  ...  ...     ...
# 18974    China PR        CB     Zhang Mengxuan   21   47   52  257710
# 18975     England        ST        V. Da Silva   17   47   67  258736
# 18976    China PR        CB             Xia Ao   21   47   55  247223
# 18977     England        CM           B. Hough   17   47   67  258760
# 18978     Bolivia       CDM          M. Flores   19   47   63  255958
#
#        Weight_lbs   foot  BOV  ... SHO  PAS DRI DEF PHY   Hits Contract_start  \
# 0             159   Left   93  ...  92   91  95  38  65  \n372           2004
# 1             183  Right   92  ...  93   81  89  35  77  \n344           2018
# 2             192  Right   91  ...  92   78  90  52  90   \n86           2014
# 3             154  Right   91  ...  86   93  88  64  78  \n163           2015
# 4             150  Right   91  ...  85   86  94  36  59  \n273           2017
# ...           ...    ...  ...  ...  ..  ...  ..  ..  ..    ...            ...
# 18974         154  Right   49  ...  23   26  27  50  48    \n2           2020
# 18975         128  Right   51  ...  46   40  53  16  40    \n3           2020
# 18976         146  Right   49  ...  28   26  38  48  51    \n3           2018
# 18977         143  Right   51  ...  40   48  49  35  45    \n5           2020
# 18978         150  Right   48  ...  32   43  48  44  49    \n2           2020
#
#        Contract_end                                Teams  Height_cm
# 0              2004                         FC Barcelona        170
# 1              2018                             Juventus        188
# 2              2014                      Atlético Madrid        188
# 3              2015                      Manchester City        180
# 4              2017                  Paris Saint-Germain        175
# ...             ...                                  ...        ...
# 18974          2020  Chongqing Dangdai Lifan FC SWM Team        178
# 18975          2020                      Oldham Athletic        170
# 18976          2018                           Wuhan Zall        178
# 18977          2020                      Oldham Athletic        175
# 18978          2020                         Club Bolívar        175
#
# [18979 rows x 76 columns]

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 76 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Nationality       18979 non-null  object
#  1   Positions         18979 non-null  object
#  2   Name              18979 non-null  object
#  3   Age               18979 non-null  int64
#  4   OVA               18979 non-null  int64
#  5   POT               18979 non-null  int64
#  6   ID                18979 non-null  int64
#  7   Weight_lbs        18979 non-null  int32
#  8   foot              18979 non-null  object
#  9   BOV               18979 non-null  int64
#  10  BP                18979 non-null  object
#  11  Growth            18979 non-null  int64
#  12  Joined            18979 non-null  object
#  13  Loan Date End     1013 non-null   object
#  14  Value             18979 non-null  object
#  15  Wage              18979 non-null  object
#  16  Release Clause    18979 non-null  object
#  17  Attacking         18979 non-null  int64
#  18  Crossing          18979 non-null  int64
#  19  Finishing         18979 non-null  int64
#  20  Heading Accuracy  18979 non-null  int64
#  21  Short Passing     18979 non-null  int64
#  22  Volleys           18979 non-null  int64
#  23  Skill             18979 non-null  int64
#  24  Dribbling         18979 non-null  int64
#  25  Curve             18979 non-null  int64
#  26  FK Accuracy       18979 non-null  int64
#  27  Long Passing      18979 non-null  int64
#  28  Ball Control      18979 non-null  int64
#  29  Movement          18979 non-null  int64
#  30  Acceleration      18979 non-null  int64
#  31  Sprint Speed      18979 non-null  int64
#  32  Agility           18979 non-null  int64
#  33  Reactions         18979 non-null  int64
#  34  Balance           18979 non-null  int64
#  35  Power             18979 non-null  int64
#  36  Shot Power        18979 non-null  int64
#  37  Jumping           18979 non-null  int64
#  38  Stamina           18979 non-null  int64
#  39  Strength          18979 non-null  int64
#  40  Long Shots        18979 non-null  int64
#  41  Mentality         18979 non-null  int64
#  42  Aggression        18979 non-null  int64
#  43  Interceptions     18979 non-null  int64
#  44  Positioning       18979 non-null  int64
#  45  Vision            18979 non-null  int64
#  46  Penalties         18979 non-null  int64
#  47  Composure         18979 non-null  int64
#  48  Defending         18979 non-null  int64
#  49  Marking           18979 non-null  int64
#  50  Standing Tackle   18979 non-null  int64
#  51  Sliding Tackle    18979 non-null  int64
#  52  Goalkeeping       18979 non-null  int64
#  53  GK Diving         18979 non-null  int64
#  54  GK Handling       18979 non-null  int64
#  55  GK Kicking        18979 non-null  int64
#  56  GK Positioning    18979 non-null  int64
#  57  GK Reflexes       18979 non-null  int64
#  58  Total Stats       18979 non-null  int64
#  59  Base Stats        18979 non-null  int64
#  60  W/F               18979 non-null  object
#  61  SM                18979 non-null  object
#  62  A/W               18979 non-null  object
#  63  D/W               18979 non-null  object
#  64  IR                18979 non-null  object
#  65  PAC               18979 non-null  int64
#  66  SHO               18979 non-null  int64
#  67  PAS               18979 non-null  int64
#  68  DRI               18979 non-null  int64
#  69  DEF               18979 non-null  int64
#  70  PHY               18979 non-null  int64
#  71  Hits              18979 non-null  object
#  72  Contract_start    18979 non-null  int32
#  73  Contract_end      18979 non-null  int32
#  74  Teams             18979 non-null  object
#  75  Height_cm         18979 non-null  int32
# dtypes: int32(4), int64(55), object(17)
# memory usage: 10.7+ MB

# %%
print(fifa['Loan Date End'])
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 18974    NaN
# 18975    NaN
# 18976    NaN
# 18977    NaN
# 18978    NaN
# Name: Loan Date End, Length: 18979, dtype: object

# %%
fifa[['Value']]
# Out:
#         Value
# 0      €67.5M
# 1        €46M
# 2        €75M
# 3        €87M
# 4        €90M
# ...       ...
# 18974    €35K
# 18975    €60K
# 18976    €40K
# 18977    €60K
# 18978    €60K
#
# [18979 rows x 1 columns]

# %%
## Convert Value to float

# %%
# Function to convert values
def convert_value(value):
    # Remove the euro symbol and treat M as (Million) and K as (Thousands)
    value = value.replace('€', '').strip()  # Use 'value' instead of 'Value'
    
    # Check for M (Millions) or K (Thousands)
    if 'M' in value:
        return float(value.replace('M', '')) * 1_000_000  # Convert millions to integers
    elif 'K' in value:
        return float(value.replace('K', '')) * 1_000  # Convert thousands to integers
    else:
        return float(value)  # In case there is no M or K, just convert directly to float

# Apply the cleaning
fifa['Value'] = fifa['Value'].apply(convert_value)

# %%
fifa[['Value']]
# Out:
#             Value
# 0      67500000.0
# 1      46000000.0
# 2      75000000.0
# 3      87000000.0
# 4      90000000.0
# ...           ...
# 18974     35000.0
# 18975     60000.0
# 18976     40000.0
# 18977     60000.0
# 18978     60000.0
#
# [18979 rows x 1 columns]

# %%
# Function to convert wage values
def convert_wage(wage):
    # Remove the euro symbol and treat M as (Million) and K as (Thousands)
    wage = wage.replace('€', '').strip()  # Use 'wage' consistently
    
    # Check for M (Millions) or K (Thousands)
    if 'M' in wage:
        return float(wage.replace('M', '')) * 1_000_000  # Convert millions to integers
    elif 'K' in wage:
        return float(wage.replace('K', '')) * 1_000  # Convert thousands to integers
    else:
        return float(wage)  # In case there is no M or K, just convert directly to float

# Apply the cleaning to the 'Wage' column
fifa['Wage'] = fifa['Wage'].apply(convert_wage)

# %%
print(fifa['Wage'].head())
# Out:
# 0    560000.0
# 1    220000.0
# 2    125000.0
# 3    370000.0
# 4    270000.0
# Name: Wage, dtype: float64

# %%
print(fifa['Release Clause'].head())
# Out:
# 0    €138.4M
# 1     €75.9M
# 2    €159.4M
# 3      €161M
# 4    €166.5M
# Name: Release Clause, dtype: object

# %%
# Function to convert release clause values
def convert_release_clause(release_clause):
    # Remove the euro symbol and treat M as (Million) and K as (Thousands)
    release_clause = release_clause.replace('€', '').strip()  # Remove '€' symbol and strip any leading/trailing spaces
    
    # Check for M (Millions) or K (Thousands)
    if 'M' in release_clause:
        return float(release_clause.replace('M', '')) * 1_000_000  # Convert millions to integers
    elif 'K' in release_clause:
        return float(release_clause.replace('K', '')) * 1_000  # Convert thousands to integers
    else:
        return float(release_clause)  # In case there is no M or K, just convert directly to float

# Apply the cleaning function to the 'Release Clause' column
fifa['Release Clause'] = fifa['Release Clause'].apply(convert_release_clause)

# %%
print(fifa['Release Clause'].head())
# Out:
# 0    138400000.0
# 1     75900000.0
# 2    159400000.0
# 3    161000000.0
# 4    166500000.0
# Name: Release Clause, dtype: float64

# %%
print(fifa['W/F'].head())
# Out:
# 0    4 ★
# 1    4 ★
# 2    3 ★
# 3    5 ★
# 4    5 ★
# Name: W/F, dtype: object

# %%
print(fifa['W/F'].unique())
# Out:
# ['4 ★' '3 ★' '5 ★' '2 ★' '1 ★']

# %%
# Removing ★ character
fifa['W/F'] = fifa['W/F'].replace({r'★': ''}, regex=True)
# Convert to int
fifa['W/F'] = fifa['W/F'].astype(int)

# %%
print(fifa['W/F'].head())
# Out:
# 0    4
# 1    4
# 2    3
# 3    5
# 4    5
# Name: W/F, dtype: int32

# %%
print(fifa['SM'].head())
# Out:
# 0    4★
# 1    5★
# 2    1★
# 3    4★
# 4    5★
# Name: SM, dtype: object

# %%
# Removing ★ character
fifa['SM'] = fifa['SM'].replace({r'★': ''}, regex=True)
# Convert to int
fifa['SM'] = fifa['SM'].astype(int)

# %%
print(fifa['SM'].head())
# Out:
# 0    4
# 1    5
# 2    1
# 3    4
# 4    5
# Name: SM, dtype: int32

# %%
print(fifa['IR'].head())
# Out:
# 0    5 ★
# 1    5 ★
# 2    3 ★
# 3    4 ★
# 4    5 ★
# Name: IR, dtype: object

# %%
# Removing ★ character
fifa['IR'] = fifa['IR'].replace({r'★': ''}, regex=True)
# Convert to int
fifa['IR'] = fifa['IR'].astype(int)

# %%
print(fifa['IR'].head())
# Out:
# 0    5
# 1    5
# 2    3
# 3    4
# 4    5
# Name: IR, dtype: int32

# %%
print(fifa['Hits'].head())
# Out:
# 0    \n372
# 1    \n344
# 2     \n86
# 3    \n163
# 4    \n273
# Name: Hits, dtype: object

# %%
# Removing spaces and new line
fifa['Hits'] = fifa['Hits'].replace({r'\n': '', r'\s+': ''}, regex=True)
# Treat 'K' as 1000 and 'M' as 1000000, # Multiplying by 1000 and 1000000 for 'K' and 'M'
fifa['Hits'] = fifa['Hits'].replace({r'K': '*1000', r'M': '*1000000'}, regex=True)
# Clean the 'Hits' column by evaluating any mathematical expressions (like '1.3*1000')
fifa['Hits'] = fifa['Hits'].map(pd.eval).astype(int)

# %%
print(fifa['Hits'])
# Out:
# 0        372
# 1        344
# 2         86
# 3        163
# 4        273
#         ...
# 18974      2
# 18975      3
# 18976      3
# 18977      5
# 18978      2
# Name: Hits, Length: 18979, dtype: int32

# %%
fifa
# Out:
#       Nationality Positions               Name  Age  OVA  POT      ID  \
# 0       Argentina  RW ST CF           L. Messi   33   93   93  158023
# 1        Portugal     ST LW  Cristiano Ronaldo   35   92   92   20801
# 2        Slovenia        GK           J. Oblak   27   91   93  200389
# 3         Belgium    CAM CM       K. De Bruyne   29   91   91  192985
# 4          Brazil    LW CAM          Neymar Jr   28   91   91  190871
# ...           ...       ...                ...  ...  ...  ...     ...
# 18974    China PR        CB     Zhang Mengxuan   21   47   52  257710
# 18975     England        ST        V. Da Silva   17   47   67  258736
# 18976    China PR        CB             Xia Ao   21   47   55  247223
# 18977     England        CM           B. Hough   17   47   67  258760
# 18978     Bolivia       CDM          M. Flores   19   47   63  255958
#
#        Weight_lbs   foot  BOV  ... SHO  PAS DRI DEF  PHY  Hits  \
# 0             159   Left   93  ...  92   91  95  38   65   372
# 1             183  Right   92  ...  93   81  89  35   77   344
# 2             192  Right   91  ...  92   78  90  52   90    86
# 3             154  Right   91  ...  86   93  88  64   78   163
# 4             150  Right   91  ...  85   86  94  36   59   273
# ...           ...    ...  ...  ...  ..  ...  ..  ..  ...   ...
# 18974         154  Right   49  ...  23   26  27  50   48     2
# 18975         128  Right   51  ...  46   40  53  16   40     3
# 18976         146  Right   49  ...  28   26  38  48   51     3
# 18977         143  Right   51  ...  40   48  49  35   45     5
# 18978         150  Right   48  ...  32   43  48  44   49     2
#
#        Contract_start  Contract_end                                Teams  \
# 0                2004          2004                         FC Barcelona
# 1                2018          2018                             Juventus
# 2                2014          2014                      Atlético Madrid
# 3                2015          2015                      Manchester City
# 4                2017          2017                  Paris Saint-Germain
# ...               ...           ...                                  ...
# 18974            2020          2020  Chongqing Dangdai Lifan FC SWM Team
# 18975            2020          2020                      Oldham Athletic
# 18976            2018          2018                           Wuhan Zall
# 18977            2020          2020                      Oldham Athletic
# 18978            2020          2020                         Club Bolívar
#
#        Height_cm
# 0            170
# 1            188
# 2            188
# 3            180
# 4            175
# ...          ...
# 18974        178
# 18975        170
# 18976        178
# 18977        175
# 18978        175
#
# [18979 rows x 76 columns]

# %%
fifa.columns
# Out:
# Index(['Nationality', 'Positions', 'Name', 'Age', 'OVA', 'POT', 'ID',
#        'Weight_lbs', 'foot', 'BOV', 'BP', 'Growth', 'Joined', 'Loan Date End',
#        'Value', 'Wage', 'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
#        'Base Stats', 'W/F', 'SM', 'A/W', 'D/W', 'IR', 'PAC', 'SHO', 'PAS',
#        'DRI', 'DEF', 'PHY', 'Hits', 'Contract_start', 'Contract_end', 'Teams',
#        'Height_cm'],
#       dtype='object')

# %%
fifa.drop(['Nationality','Name','Positions','BP','ID','foot','Sprint Speed','Reactions','Composure','GK Handling','GK Kicking','GK Positioning','Base Stats','W/F', 'SM', 'A/W', 'D/W','IR'],inplace = True, axis = 1)

# %%
fifa.columns
# Out:
# Index(['Age', 'OVA', 'POT', 'Weight_lbs', 'BOV', 'Growth', 'Joined',
#        'Loan Date End', 'Value', 'Wage', 'Release Clause', 'Attacking',
#        'Crossing', 'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys',
#        'Skill', 'Dribbling', 'Curve', 'FK Accuracy', 'Long Passing',
#        'Ball Control', 'Movement', 'Acceleration', 'Agility', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Reflexes',
#        'Total Stats', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY', 'Hits',
#        'Contract_start', 'Contract_end', 'Teams', 'Height_cm'],
#       dtype='object')

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 58 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               18979 non-null  int64
#  1   OVA               18979 non-null  int64
#  2   POT               18979 non-null  int64
#  3   Weight_lbs        18979 non-null  int32
#  4   BOV               18979 non-null  int64
#  5   Growth            18979 non-null  int64
#  6   Joined            18979 non-null  object
#  7   Loan Date End     1013 non-null   object
#  8   Value             18979 non-null  float64
#  9   Wage              18979 non-null  float64
#  10  Release Clause    18979 non-null  float64
#  11  Attacking         18979 non-null  int64
#  12  Crossing          18979 non-null  int64
#  13  Finishing         18979 non-null  int64
#  14  Heading Accuracy  18979 non-null  int64
#  15  Short Passing     18979 non-null  int64
#  16  Volleys           18979 non-null  int64
#  17  Skill             18979 non-null  int64
#  18  Dribbling         18979 non-null  int64
#  19  Curve             18979 non-null  int64
#  20  FK Accuracy       18979 non-null  int64
#  21  Long Passing      18979 non-null  int64
#  22  Ball Control      18979 non-null  int64
#  23  Movement          18979 non-null  int64
#  24  Acceleration      18979 non-null  int64
#  25  Agility           18979 non-null  int64
#  26  Balance           18979 non-null  int64
#  27  Power             18979 non-null  int64
#  28  Shot Power        18979 non-null  int64
#  29  Jumping           18979 non-null  int64
#  30  Stamina           18979 non-null  int64
#  31  Strength          18979 non-null  int64
#  32  Long Shots        18979 non-null  int64
#  33  Mentality         18979 non-null  int64
#  34  Aggression        18979 non-null  int64
#  35  Interceptions     18979 non-null  int64
#  36  Positioning       18979 non-null  int64
#  37  Vision            18979 non-null  int64
#  38  Penalties         18979 non-null  int64
#  39  Defending         18979 non-null  int64
#  40  Marking           18979 non-null  int64
#  41  Standing Tackle   18979 non-null  int64
#  42  Sliding Tackle    18979 non-null  int64
#  43  Goalkeeping       18979 non-null  int64
#  44  GK Diving         18979 non-null  int64
#  45  GK Reflexes       18979 non-null  int64
#  46  Total Stats       18979 non-null  int64
#  47  PAC               18979 non-null  int64
#  48  SHO               18979 non-null  int64
#  49  PAS               18979 non-null  int64
#  50  DRI               18979 non-null  int64
#  51  DEF               18979 non-null  int64
#  52  PHY               18979 non-null  int64
#  53  Hits              18979 non-null  int32
#  54  Contract_start    18979 non-null  int32
#  55  Contract_end      18979 non-null  int32
#  56  Teams             18979 non-null  object
#  57  Height_cm         18979 non-null  int32
# dtypes: float64(3), int32(5), int64(47), object(3)
# memory usage: 8.0+ MB

# %%
print(fifa['Joined'])
# Out:
# 0         Jul 1, 2004
# 1        Jul 10, 2018
# 2        Jul 16, 2014
# 3        Aug 30, 2015
# 4         Aug 3, 2017
#              ...
# 18974     Aug 1, 2020
# 18975     Aug 1, 2020
# 18976    Jul 13, 2018
# 18977     Aug 1, 2020
# 18978     Jan 1, 2020
# Name: Joined, Length: 18979, dtype: object

# %%
print(fifa['Joined'])
# Out:
# 0         Jul 1, 2004
# 1        Jul 10, 2018
# 2        Jul 16, 2014
# 3        Aug 30, 2015
# 4         Aug 3, 2017
#              ...
# 18974     Aug 1, 2020
# 18975     Aug 1, 2020
# 18976    Jul 13, 2018
# 18977     Aug 1, 2020
# 18978     Jan 1, 2020
# Name: Joined, Length: 18979, dtype: object

# %%
import pandas as pd

# Sample dataframe with a date column
df = pd.DataFrame({
    'Date': ['Jul 1, 2004', 'Jul 10, 2018', 'Jul 16, 2014'],
    'Feature1': [0.5, 0.2, -0.3],
    'Feature2': [1.0, 0.8, 0.3]
})

# Convert the 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Extract relevant features (for example, the year, month, and day)
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day

# %%
# Now, drop the original 'Date' column if not needed
df = df.drop(columns=['Date'])

print(df)
# Out:
#    Feature1  Feature2  Year  Month  Day
# 0       0.5       1.0  2004      7    1
# 1       0.2       0.8  2018      7   10
# 2      -0.3       0.3  2014      7   16

# %%
df = pd.get_dummies(df, drop_first=True)  # One-hot encoding for categorical columns

# %%
fifa
# Out:
#        Age  OVA  POT  Weight_lbs  BOV  Growth        Joined Loan Date End  \
# 0       33   93   93         159   93       0   Jul 1, 2004           NaN
# 1       35   92   92         183   92       0  Jul 10, 2018           NaN
# 2       27   91   93         192   91       2  Jul 16, 2014           NaN
# 3       29   91   91         154   91       0  Aug 30, 2015           NaN
# 4       28   91   91         150   91       0   Aug 3, 2017           NaN
# ...    ...  ...  ...         ...  ...     ...           ...           ...
# 18974   21   47   52         154   49       5   Aug 1, 2020           NaN
# 18975   17   47   67         128   51      20   Aug 1, 2020           NaN
# 18976   21   47   55         146   49       8  Jul 13, 2018           NaN
# 18977   17   47   67         143   51      20   Aug 1, 2020           NaN
# 18978   19   47   63         150   48      16   Jan 1, 2020           NaN
#
#             Value      Wage  ...  SHO  PAS  DRI  DEF  PHY  Hits  \
# 0      67500000.0  560000.0  ...   92   91   95   38   65   372
# 1      46000000.0  220000.0  ...   93   81   89   35   77   344
# 2      75000000.0  125000.0  ...   92   78   90   52   90    86
# 3      87000000.0  370000.0  ...   86   93   88   64   78   163
# 4      90000000.0  270000.0  ...   85   86   94   36   59   273
# ...           ...       ...  ...  ...  ...  ...  ...  ...   ...
# 18974     35000.0    1000.0  ...   23   26   27   50   48     2
# 18975     60000.0     500.0  ...   46   40   53   16   40     3
# 18976     40000.0    1000.0  ...   28   26   38   48   51     3
# 18977     60000.0     500.0  ...   40   48   49   35   45     5
# 18978     60000.0     500.0  ...   32   43   48   44   49     2
#
#        Contract_start  Contract_end                                Teams  \
# 0                2004          2004                         FC Barcelona
# 1                2018          2018                             Juventus
# 2                2014          2014                      Atlético Madrid
# 3                2015          2015                      Manchester City
# 4                2017          2017                  Paris Saint-Germain
# ...               ...           ...                                  ...
# 18974            2020          2020  Chongqing Dangdai Lifan FC SWM Team
# 18975            2020          2020                      Oldham Athletic
# 18976            2018          2018                           Wuhan Zall
# 18977            2020          2020                      Oldham Athletic
# 18978            2020          2020                         Club Bolívar
#
#        Height_cm
# 0            170
# 1            188
# 2            188
# 3            180
# 4            175
# ...          ...
# 18974        178
# 18975        170
# 18976        178
# 18977        175
# 18978        175
#
# [18979 rows x 58 columns]

# %%
print(fifa['Teams'])
# Out:
# 0                               FC Barcelona
# 1                                   Juventus
# 2                            Atlético Madrid
# 3                            Manchester City
# 4                        Paris Saint-Germain
#                         ...
# 18974    Chongqing Dangdai Lifan FC SWM Team
# 18975                        Oldham Athletic
# 18976                             Wuhan Zall
# 18977                        Oldham Athletic
# 18978                           Club Bolívar
# Name: Teams, Length: 18979, dtype: object

# %%
Team1 = {'Teams': ['FC Barcelona', 'Juventus', 'Atlético Madrid', 'Manchester City', 'Paris Saint-Germain']}

df = pd.DataFrame(fifa)  # This defines the DataFrame with the 'Teams' column

# %%
import pandas as pd

Team1 = {'Teams': ['FC Barcelona', 'Juventus', 'Atlético Madrid', 'Manchester City', 'Paris Saint-Germain']}

df = pd.DataFrame(fifa)

# %%
# Label encode the 'Teams' column by assigning a unique integer to each unique team
fifa['Teams'] = pd.factorize(df['Teams'])[0]

# Check the result
print(df[['Teams']].head(5))
# Out:
#                  Teams
# 0         FC Barcelona
# 1             Juventus
# 2      Atlético Madrid
# 3      Manchester City
# 4  Paris Saint-Germain

# %%
# Example DataFrame with team names
Team1 = {'Teams': ['FC Barcelona', 'Juventus', 'Atlético Madrid', 'Manchester City', 'Paris Saint-Germain']}
df = pd.DataFrame(fifa)

# Use factorize on the 'Teams' column
df['Teams'] = pd.factorize(df['Teams'])[0]

# %%
print(df[['Teams']].head(5))
# Out:
#    Teams
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4

# %%
Team1 = {'Teams': ['FC Barcelona', 'Juventus', 'Atlético Madrid', 'Manchester City', 'Paris Saint-Germain']}
df = pd.DataFrame(fifa)

# Use factorize on the 'Teams' column to convert team names to integer labels
df['Teams'] = pd.factorize(df['Teams'])[0]

# %%
# Convert teams column to int
df['Teams'] = df['Teams'].astype(int)

# %%
print(df[['Teams']].head(5))
# Out:
#    Teams
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4

# %%
print(df['Teams'].dtype)
# Out:
# int32

# %%
print(fifa['Loan Date End'])
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 18974    NaN
# 18975    NaN
# 18976    NaN
# 18977    NaN
# 18978    NaN
# Name: Loan Date End, Length: 18979, dtype: object

# %%
fifa['Loan Date End']=fifa['Loan Date End'].fillna('Not Available')

# %%
fifa
# Out:
#        Age  OVA  POT  Weight_lbs  BOV  Growth        Joined  Loan Date End  \
# 0       33   93   93         159   93       0   Jul 1, 2004  Not Available
# 1       35   92   92         183   92       0  Jul 10, 2018  Not Available
# 2       27   91   93         192   91       2  Jul 16, 2014  Not Available
# 3       29   91   91         154   91       0  Aug 30, 2015  Not Available
# 4       28   91   91         150   91       0   Aug 3, 2017  Not Available
# ...    ...  ...  ...         ...  ...     ...           ...            ...
# 18974   21   47   52         154   49       5   Aug 1, 2020  Not Available
# 18975   17   47   67         128   51      20   Aug 1, 2020  Not Available
# 18976   21   47   55         146   49       8  Jul 13, 2018  Not Available
# 18977   17   47   67         143   51      20   Aug 1, 2020  Not Available
# 18978   19   47   63         150   48      16   Jan 1, 2020  Not Available
#
#             Value      Wage  ...  SHO  PAS  DRI  DEF  PHY  Hits  \
# 0      67500000.0  560000.0  ...   92   91   95   38   65   372
# 1      46000000.0  220000.0  ...   93   81   89   35   77   344
# 2      75000000.0  125000.0  ...   92   78   90   52   90    86
# 3      87000000.0  370000.0  ...   86   93   88   64   78   163
# 4      90000000.0  270000.0  ...   85   86   94   36   59   273
# ...           ...       ...  ...  ...  ...  ...  ...  ...   ...
# 18974     35000.0    1000.0  ...   23   26   27   50   48     2
# 18975     60000.0     500.0  ...   46   40   53   16   40     3
# 18976     40000.0    1000.0  ...   28   26   38   48   51     3
# 18977     60000.0     500.0  ...   40   48   49   35   45     5
# 18978     60000.0     500.0  ...   32   43   48   44   49     2
#
#        Contract_start  Contract_end  Teams  Height_cm
# 0                2004          2004      0        170
# 1                2018          2018      1        188
# 2                2014          2014      2        188
# 3                2015          2015      3        180
# 4                2017          2017      4        175
# ...               ...           ...    ...        ...
# 18974            2020          2020    196        178
# 18975            2020          2020    649        170
# 18976            2018          2018    152        178
# 18977            2020          2020    649        175
# 18978            2020          2020    505        175
#
# [18979 rows x 58 columns]

# %%
print(fifa['Loan Date End'])
# Out:
# 0        Not Available
# 1        Not Available
# 2        Not Available
# 3        Not Available
# 4        Not Available
#              ...
# 18974    Not Available
# 18975    Not Available
# 18976    Not Available
# 18977    Not Available
# 18978    Not Available
# Name: Loan Date End, Length: 18979, dtype: object

# %%
fifa
# Out:
#        Age  OVA  POT  Weight_lbs  BOV  Growth        Joined  Loan Date End  \
# 0       33   93   93         159   93       0   Jul 1, 2004  Not Available
# 1       35   92   92         183   92       0  Jul 10, 2018  Not Available
# 2       27   91   93         192   91       2  Jul 16, 2014  Not Available
# 3       29   91   91         154   91       0  Aug 30, 2015  Not Available
# 4       28   91   91         150   91       0   Aug 3, 2017  Not Available
# ...    ...  ...  ...         ...  ...     ...           ...            ...
# 18974   21   47   52         154   49       5   Aug 1, 2020  Not Available
# 18975   17   47   67         128   51      20   Aug 1, 2020  Not Available
# 18976   21   47   55         146   49       8  Jul 13, 2018  Not Available
# 18977   17   47   67         143   51      20   Aug 1, 2020  Not Available
# 18978   19   47   63         150   48      16   Jan 1, 2020  Not Available
#
#             Value      Wage  ...  SHO  PAS  DRI  DEF  PHY  Hits  \
# 0      67500000.0  560000.0  ...   92   91   95   38   65   372
# 1      46000000.0  220000.0  ...   93   81   89   35   77   344
# 2      75000000.0  125000.0  ...   92   78   90   52   90    86
# 3      87000000.0  370000.0  ...   86   93   88   64   78   163
# 4      90000000.0  270000.0  ...   85   86   94   36   59   273
# ...           ...       ...  ...  ...  ...  ...  ...  ...   ...
# 18974     35000.0    1000.0  ...   23   26   27   50   48     2
# 18975     60000.0     500.0  ...   46   40   53   16   40     3
# 18976     40000.0    1000.0  ...   28   26   38   48   51     3
# 18977     60000.0     500.0  ...   40   48   49   35   45     5
# 18978     60000.0     500.0  ...   32   43   48   44   49     2
#
#        Contract_start  Contract_end  Teams  Height_cm
# 0                2004          2004      0        170
# 1                2018          2018      1        188
# 2                2014          2014      2        188
# 3                2015          2015      3        180
# 4                2017          2017      4        175
# ...               ...           ...    ...        ...
# 18974            2020          2020    196        178
# 18975            2020          2020    649        170
# 18976            2018          2018    152        178
# 18977            2020          2020    649        175
# 18978            2020          2020    505        175
#
# [18979 rows x 58 columns]

# %%
fifa.drop(['Loan Date End'], inplace = True, axis = 1)

# %%
fifa
# Out:
#        Age  OVA  POT  Weight_lbs  BOV  Growth        Joined       Value  \
# 0       33   93   93         159   93       0   Jul 1, 2004  67500000.0
# 1       35   92   92         183   92       0  Jul 10, 2018  46000000.0
# 2       27   91   93         192   91       2  Jul 16, 2014  75000000.0
# 3       29   91   91         154   91       0  Aug 30, 2015  87000000.0
# 4       28   91   91         150   91       0   Aug 3, 2017  90000000.0
# ...    ...  ...  ...         ...  ...     ...           ...         ...
# 18974   21   47   52         154   49       5   Aug 1, 2020     35000.0
# 18975   17   47   67         128   51      20   Aug 1, 2020     60000.0
# 18976   21   47   55         146   49       8  Jul 13, 2018     40000.0
# 18977   17   47   67         143   51      20   Aug 1, 2020     60000.0
# 18978   19   47   63         150   48      16   Jan 1, 2020     60000.0
#
#            Wage  Release Clause  ...  SHO  PAS  DRI  DEF  PHY  Hits  \
# 0      560000.0     138400000.0  ...   92   91   95   38   65   372
# 1      220000.0      75900000.0  ...   93   81   89   35   77   344
# 2      125000.0     159400000.0  ...   92   78   90   52   90    86
# 3      370000.0     161000000.0  ...   86   93   88   64   78   163
# 4      270000.0     166500000.0  ...   85   86   94   36   59   273
# ...         ...             ...  ...  ...  ...  ...  ...  ...   ...
# 18974    1000.0         57000.0  ...   23   26   27   50   48     2
# 18975     500.0        165000.0  ...   46   40   53   16   40     3
# 18976    1000.0         70000.0  ...   28   26   38   48   51     3
# 18977     500.0        165000.0  ...   40   48   49   35   45     5
# 18978     500.0        167000.0  ...   32   43   48   44   49     2
#
#        Contract_start  Contract_end  Teams  Height_cm
# 0                2004          2004      0        170
# 1                2018          2018      1        188
# 2                2014          2014      2        188
# 3                2015          2015      3        180
# 4                2017          2017      4        175
# ...               ...           ...    ...        ...
# 18974            2020          2020    196        178
# 18975            2020          2020    649        170
# 18976            2018          2018    152        178
# 18977            2020          2020    649        175
# 18978            2020          2020    505        175
#
# [18979 rows x 57 columns]

# %%
fifa.columns
# Out:
# Index(['Age', 'OVA', 'POT', 'Weight_lbs', 'BOV', 'Growth', 'Joined', 'Value',
#        'Wage', 'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Agility', 'Balance', 'Power', 'Shot Power', 'Jumping',
#        'Stamina', 'Strength', 'Long Shots', 'Mentality', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Defending',
#        'Marking', 'Standing Tackle', 'Sliding Tackle', 'Goalkeeping',
#        'GK Diving', 'GK Reflexes', 'Total Stats', 'PAC', 'SHO', 'PAS', 'DRI',
#        'DEF', 'PHY', 'Hits', 'Contract_start', 'Contract_end', 'Teams',
#        'Height_cm'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

sc=StandardScaler()
fifa['Value']=sc.fit_transform(np.array(fifa['Value']).reshape(-1,1))

# %%
fifa
# Out:
#        Age  OVA  POT  Weight_lbs  BOV  Growth        Joined      Value  \
# 0       33   93   93         159   93       0   Jul 1, 2004  12.804571
# 1       35   92   92         183   92       0  Jul 10, 2018   8.586801
# 2       27   91   93         192   91       2  Jul 16, 2014  14.275886
# 3       29   91   91         154   91       0  Aug 30, 2015  16.629991
# 4       28   91   91         150   91       0   Aug 3, 2017  17.218517
# ...    ...  ...  ...         ...  ...     ...           ...        ...
# 18974   21   47   52         154   49       5   Aug 1, 2020  -0.430400
# 18975   17   47   67         128   51      20   Aug 1, 2020  -0.425495
# 18976   21   47   55         146   49       8  Jul 13, 2018  -0.429419
# 18977   17   47   67         143   51      20   Aug 1, 2020  -0.425495
# 18978   19   47   63         150   48      16   Jan 1, 2020  -0.425495
#
#            Wage  Release Clause  ...  SHO  PAS  DRI  DEF  PHY  Hits  \
# 0      560000.0     138400000.0  ...   92   91   95   38   65   372
# 1      220000.0      75900000.0  ...   93   81   89   35   77   344
# 2      125000.0     159400000.0  ...   92   78   90   52   90    86
# 3      370000.0     161000000.0  ...   86   93   88   64   78   163
# 4      270000.0     166500000.0  ...   85   86   94   36   59   273
# ...         ...             ...  ...  ...  ...  ...  ...  ...   ...
# 18974    1000.0         57000.0  ...   23   26   27   50   48     2
# 18975     500.0        165000.0  ...   46   40   53   16   40     3
# 18976    1000.0         70000.0  ...   28   26   38   48   51     3
# 18977     500.0        165000.0  ...   40   48   49   35   45     5
# 18978     500.0        167000.0  ...   32   43   48   44   49     2
#
#        Contract_start  Contract_end  Teams  Height_cm
# 0                2004          2004      0        170
# 1                2018          2018      1        188
# 2                2014          2014      2        188
# 3                2015          2015      3        180
# 4                2017          2017      4        175
# ...               ...           ...    ...        ...
# 18974            2020          2020    196        178
# 18975            2020          2020    649        170
# 18976            2018          2018    152        178
# 18977            2020          2020    649        175
# 18978            2020          2020    505        175
#
# [18979 rows x 57 columns]

# %%
X_train = fifa[['Age', 'Weight_lbs', 'BOV', 'Growth', 'Joined', 'Release Clause', 'Attacking', 'Crossing', 'Finishing','Heading Accuracy', 
        'Short Passing', 'Volleys', 'Skill', 'Dribbling',
       'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
       'Acceleration', 'Agility', 'Balance', 'Power', 'Shot Power', 'Jumping',
       'Stamina', 'Strength', 'Long Shots', 'Mentality', 'Aggression',
       'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Defending',
       'Marking', 'Standing Tackle', 'Sliding Tackle', 'Goalkeeping',
       'GK Diving', 'GK Reflexes', 'Total Stats', 'PAC', 'SHO', 'PAS', 'DRI',
       'DEF', 'PHY', 'Hits', 'Contract_start', 'Contract_end', 'Teams',
       'Height_cm']]

y_train = fifa['Value']

# %%
from sklearn.model_selection import train_test_split

# Define 'X' as the features (input variables), excluding the target column 'Value'
X = fifa.drop(columns=['Value'])

# Define 'y' as the target variable (what you're trying to predict)
y = fifa['Value']

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)

# %%
np.array(y_test)
# Out:
# array([ 0.50437603, -0.2214728 , -0.39803063, ..., -0.36860432,
#         0.93596182, -0.28032541])

# %%
X_test
# Out:
#        Age  OVA  POT  Weight_lbs  BOV  Growth        Joined     Wage  \
# 3478    22   72   81         148   74       9  Aug 17, 2019   6000.0
# 5782    27   69   71         170   71       2   Aug 1, 2020   7000.0
# 16115   23   59   66         212   61       7  Apr 11, 2017   2000.0
# 18894   26   49   52         159   51       3  Feb 28, 2015   1000.0
# 12579   24   63   66         172   64       3  Jan 12, 2019    650.0
# ...    ...  ...  ...         ...  ...     ...           ...      ...
# 1152    28   77   77         176   77       0  Jan 12, 2016  42000.0
# 18128   18   53   67         174   56      14   Jan 1, 2020    500.0
# 13817   26   62   66         154   64       4   Jul 2, 2019   3000.0
# 2386    25   74   78         152   76       4  Aug 30, 2018  15000.0
# 7828    28   67   67         168   67       0   May 6, 2020   6000.0
#
#        Release Clause  Attacking  ...  SHO  PAS  DRI  DEF  PHY  Hits  \
# 3478       11000000.0        320  ...   69   72   76   52   60    20
# 5782        2000000.0        273  ...   41   58   50   70   72     6
# 16115        330000.0        167  ...   20   30   35   57   77     6
# 18894         57000.0        215  ...   40   51   49   34   46     1
# 12579        563000.0        227  ...   43   52   61   59   73     2
# ...               ...        ...  ...  ...  ...  ...  ...  ...   ...
# 1152       17100000.0        354  ...   73   79   73   62   75    29
# 18128        234000.0        196  ...   34   45   51   51   60     3
# 13817        639000.0        184  ...   31   35   37   62   70     2
# 2386       10300000.0        331  ...   71   75   74   64   65    29
# 7828        1300000.0        322  ...   66   62   67   32   70     6
#
#        Contract_start  Contract_end  Teams  Height_cm
# 3478             2019          2019    355        175
# 5782             2020          2020    274        180
# 16115            2017          2017    460        196
# 18894            2015          2015    177        178
# 12579            2019          2019    687        185
# ...               ...           ...    ...        ...
# 1152             2016          2016     37        183
# 18128            2020          2020    270        188
# 13817            2019          2019    654        178
# 2386             2018          2018     76        178
# 7828             2020          2020    373        178
#
# [3796 rows x 56 columns]

# %%
y_test
# Out:
# 3478     0.504376
# 5782    -0.221473
# 16115   -0.398031
# 18894   -0.430400
# 12579   -0.353891
#            ...
# 1152     1.328313
# 18128   -0.415686
# 13817   -0.368604
# 2386     0.935962
# 7828    -0.280325
# Name: Value, Length: 3796, dtype: float64

# %%
y_train
# Out:
# 10031   -0.314656
# 16513   -0.388222
# 15725   -0.399992
# 17698   -0.407839
# 753      1.916839
#            ...
# 500      1.132137
# 12077   -0.344082
# 15277   -0.373509
# 4517     0.112025
# 5925    -0.182238
# Name: Value, Length: 15183, dtype: float64

# %%
import pandas as pd

# Sample data with date strings
data = {'Date': ['Jul 5, 2018', 'Feb 15, 2017', 'Sep 22, 2015'],
        'Feature1': [0.5, 0.2, -0.3],
        'Feature2': [1.0, 0.8, 0.3]}

df = pd.DataFrame(data)

# Convert the 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Extract year, month, and day as numeric features
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day

# Now, you can drop the original 'Date' column if it's no longer needed
df = df.drop(columns=['Date'])

# Show the resulting dataframe
print(df)
# Out:
#    Feature1  Feature2  Year  Month  Day
# 0       0.5       1.0  2018      7    5
# 1       0.2       0.8  2017      2   15
# 2      -0.3       0.3  2015      9   22

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Train the model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions
computer_prediction = model.predict(X_test)

# For regression, use mean squared error
mse = mean_squared_error(y_test, computer_prediction)
print(f'Mean Squared Error: {mse}')

# If you are doing classification, accuracy_score can be used:
# accuracy = accuracy_score(y_test, computer_prediction)
# print(f'Accuracy: {accuracy}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2964\1278517419.py in ?()
#       2 from sklearn.metrics import mean_squared_error
#       3
#       4 # Train the model
#       5 model = LinearRegression()
# ----> 6 model.fit(X_train, y_train)
#       7
#       8 # Make predictions
#       9 computer_prediction = model.predict(X_test)
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py in ?(self, X, y, sample_weight)
#     605         n_jobs_ = self.n_jobs
#     606
#     607         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     608
# --> 609         X, y = self._validate_data(
#     610             X,
#     611             y,
#     612             accept_sparse=accept_sparse,
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     646                 if "estimator" not in check_y_params:
#     647                     check_y_params = {**default_check_params, **check_y_params}
#     648                 y = check_array(y, input_name="y", **check_y_params)
#     649             else:
# --> 650                 X, y = check_X_y(X, y, **check_params)
#     651             out = X, y
#     652
#     653         if not no_val_X and check_params.get("ensure_2d", True):
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py in ?(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1297         raise ValueError(
#    1298             f"{estimator_name} requires y to be passed, but the target y is None"
#    1299         )
#    1300
# -> 1301     X = check_array(
#    1302         X,
#    1303         accept_sparse=accept_sparse,
#    1304         accept_large_sparse=accept_large_sparse,
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1009                         )
#    1010                     array = xp.astype(array, dtype, copy=False)
#    1011                 else:
#    1012                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1013             except ComplexWarning as complex_warning:
#    1014                 raise ValueError(
#    1015                     "Complex data not supported\n{}\n".format(array)
#    1016                 ) from complex_warning
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     747         # Use NumPy API to support order
#     748         if copy is True:
#     749             array = numpy.array(array, order=order, dtype=dtype)
#     750         else:
# --> 751             array = numpy.asarray(array, order=order, dtype=dtype)
#     752
#     753         # At this point array is a NumPy ndarray. We convert it to an array
#     754         # container that is consistent with the input's namespace.
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'Jul 5, 2018'

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

# Initialize your model
model = LinearRegression()

# Perform cross-validation with Linear Regression
cv_scores = cross_val_score(model, X, y, cv=5, scoring='neg_mean_squared_error')

# Print average cross-validation score (mean MSE)
print(f'Average Cross-Validation MSE: {-cv_scores.mean()}')
